# %%
import pandas as pd

# %%
# dataframe
data = {'country': ['Belgium', 'France', 'Germany', 'Netherlands', 'United Kingdom'],
        'population': [11.3, 64.3, 81.3, 16.9, 64.9],
        'area': [30510, 671308, 357050, 41526, 244820],
        'capital': ['Brussels', 'Paris', 'Berlin', 'Amsterdam', 'London']}
countries = pd.DataFrame(data)
countries = countries.set_index('country') # 인덱스 지정
countries
# Out:
#                 population    area    capital
# country
# Belgium               11.3   30510   Brussels
# France                64.3  671308      Paris
# Germany               81.3  357050     Berlin
# Netherlands           16.9   41526  Amsterdam
# United Kingdom        64.9  244820     London

# %%
countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Belgium to United Kingdom
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   population  5 non-null      float64
#  1   area        5 non-null      int64
#  2   capital     5 non-null      object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 160.0+ bytes

# %% [markdown]
# ---
#
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 인구밀도를 의미하는 `density` 칼럼을 추가하세요. (주의: 현재 'population' 칼럼은 100만 단위로 표기되어 있습니다)
#
# </div>

# %%
countries
# Out:
#                 population    area    capital
# country
# Belgium               11.3   30510   Brussels
# France                64.3  671308      Paris
# Germany               81.3  357050     Berlin
# Netherlands           16.9   41526  Amsterdam
# United Kingdom        64.9  244820     London

# %%
countries['density'] = countries['population']*1000000 / countries['area']
countries
# Out:
#                 population    area    capital     density
# country
# Belgium               11.3   30510   Brussels  370.370370
# France                64.3  671308      Paris   95.783158
# Germany               81.3  357050     Berlin  227.699202
# Netherlands           16.9   41526  Amsterdam  406.973944
# United Kingdom        64.9  244820     London  265.092721

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 인구밀도가 300을 초과하는 국가(country)의 수도(capital)과 인구(population)을 선택해주세요.
#
# </div>

# %%
countries.loc[
    countries['density'] > 300,
    ['capital', 'population']
]
# Out:
#                capital  population
# country
# Belgium       Brussels        11.3
# Netherlands  Amsterdam        16.9

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 'density_ratio' 칼럼을 추가해주세요. (density_ratio = 인구밀도/평균 인구밀도)
# </div>

# %%
countries['density_ration'] = countries['density'] / countries['density'].mean()
countries
# Out:
#                 population    area    capital     density  density_ration
# country
# Belgium               11.3   30510   Brussels  370.370370        1.355755
# France                64.3  671308      Paris   95.783158        0.350618
# Germany               81.3  357050     Berlin  227.699202        0.833502
# Netherlands           16.9   41526  Amsterdam  406.973944        1.489744
# United Kingdom        64.9  244820     London  265.092721        0.970382

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 영국(United Kingdom)의 수도(capital)를 'Cambridge'로 변경해주세요.
# </div>

# %%
countries.loc['United Kingdom','capital'] = 'Cambridge'

# %%
countries
# Out:
#                 population    area    capital     density  density_ration
# country
# Belgium               11.3   30510   Brussels  370.370370        1.355755
# France                64.3  671308      Paris   95.783158        0.350618
# Germany               81.3  357050     Berlin  227.699202        0.833502
# Netherlands           16.9   41526  Amsterdam  406.973944        1.489744
# United Kingdom        64.9  244820  Cambridge  265.092721        0.970382

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 인구 밀도가 100 초과, 300 미만인 국가들을 표시해주세요.
# </div>

# %%
countries[
    (countries['density'] > 100) & (countries['density'] < 300)
]
# Out:
#                 population    area    capital     density  density_ration
# country
# Germany               81.3  357050     Berlin  227.699202        0.833502
# United Kingdom        64.9  244820  Cambridge  265.092721        0.970382

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 수도가 7글자 이상인 국가들을 표시해주세요. (힌트: string의 len( )를 사용하세요.)
# </div>

# %%
countries[
    countries['capital'].str.len() >= 7
]
# Out:
#                 population    area    capital     density  density_ration
# country
# Belgium               11.3   30510   Brussels  370.370370        1.355755
# Netherlands           16.9   41526  Amsterdam  406.973944        1.489744
# United Kingdom        64.9  244820  Cambridge  265.092721        0.970382

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 수도에 'am' 이 포함되는 국가들을 표시해주세요. (힌트: string의 contains( )를 사용하세요.)
# </div>

# %%
countries[
    countries['capital'].str.contains('am')
]
# Out:
#                 population    area    capital     density  density_ration
# country
# Netherlands           16.9   41526  Amsterdam  406.973944        1.489744
# United Kingdom        64.9  244820  Cambridge  265.092721        0.970382

# %% [markdown]
# # 영화리뷰 데이터에서 자료 찾기

# %% [markdown]
# movie_title_data.tsv 읽어오기

# %% [markdown]
# https://drive.google.com/file/d/1cvBtLVyfhfodJK-BXWqBLcopyus9HOIc/view?usp=sharing

# %%
titles = pd.read_csv('./data/movie_title_data.tsv',sep='\t')
titles
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9044\3005643854.py:1: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   titles = pd.read_csv('./data/movie_title_data.tsv',sep='\t')
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 8407394  tt9916848  tvEpisode              Episode #3.17
# 8407395  tt9916850  tvEpisode              Episode #3.19
# 8407396  tt9916852  tvEpisode              Episode #3.20
# 8407397  tt9916856      short                   The Wind
# 8407398  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894      \N              1
# 1           Le clown et ses chiens       0      1892      \N              5
# 2                   Pauvre Pierrot       0      1892      \N              4
# 3                      Un bon bock       0      1892      \N             12
# 4                 Blacksmith Scene       0      1893      \N              1
# ...                            ...     ...       ...     ...            ...
# 8407394              Episode #3.17       0      2010      \N             \N
# 8407395              Episode #3.19       0      2010      \N             \N
# 8407396              Episode #3.20       0      2010      \N             \N
# 8407397                   The Wind       0      2015      \N             27
# 8407398  Horrid Henry Knows It All       0      2014      \N             10
#
#                              genres
# 0                 Documentary,Short
# 1                   Animation,Short
# 2          Animation,Comedy,Romance
# 3                   Animation,Short
# 4                      Comedy,Short
# ...                             ...
# 8407394         Action,Drama,Family
# 8407395         Action,Drama,Family
# 8407396         Action,Drama,Family
# 8407397                       Short
# 8407398  Adventure,Animation,Comedy
#
# [8407399 rows x 9 columns]

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: titles 데이터프레임에는 몇 개의 영화가 기록되어 있나요?
# </div>

# %%
titles.shape[0]
# Out:
# 8407399

# %%
len(titles)
# Out:
# 8407399

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: titles에서 가장 빠른 시기에 제작된 영화 두 개를 표시하세요.  힌트: .sort_values()
# </div>

# %%
titles['startYear'].apply(lambda x : int(x) if x !='\\N' else None)
# Out:
# 0          1894
# 1          1892
# 2          1892
# 3          1892
# 4          1893
#            ...
# 8407394    2010
# 8407395    2010
# 8407396    2010
# 8407397    2015
# 8407398    2014
# Name: startYear, Length: 8407399, dtype: int64

# %%
titles['startYear'].unique()
# Out:
# array([1894, 1892, 1893, 1895, 1896, 1898, 1897, 1900, 1899, 1901, 1902,
#        1903, 1905, 1904, 1912, 1907, 1906, 1908, 1910, 1909, 1914, 1911,
#        1913, 1915, 1919, 1916, 1917, 1918, 1936, 1925, 1920, 1922, 1921,
#        1923, 2019, 1924, 1928, 1926, 1927, 1929, 2000, 1993, 1935, 2014,
#        1930, 1942, 1934, 1931, 1932, 1939, 1937, 1933, 1950, 1938, 1951,
#        1945, 1946, 1996, 1940, 1944, 1949, 1947, 1941, 1952, 1970, 1957,
#        1943, 1959, 1948, 2001, 1953, 2008, 1954, 1965, 1983, 1980, 1973,
#        1961, 1995, 1955, 1962, 1958, 1956, 1977, 1960, 1964, 1967, 1968,
#        1963, 1986, 1971, 1969, 1972, 1966, 2021, 2002, 1976, 1990, 2020,
#        1979, 1974, 1978, 1981, 1988, 1975, 1989, '1971', '1972', '1970',
#        '1974', '1973', '1976', '1969', '1968', '1985', '\\N', '1981',
#        '2009', '1980', '1986', '1965', '1987', '1975', '1978', '1967',
#        '1990', '1977', '2010', '2018', '1979', '2007', '1989', '1983',
#        '1988', '1984', '1966', '1982', '1992', '1991', '1952', '1963',
#        '2001', '1961', '1994', '1993', '1964', '1957', '1999', '1995',
#        '2019', '2005', '1953', '2004', '1998', '1947', '2002', '1997',
#        '1959', '1996', '2017', '2000', '1945', '1956', '2021', '2013',
#        '2016', '2006', '2003', '1955', '1949', '2008', '1960', '1930',
#        '1938', '1929', '1944', '1935', '1962', '1919', '1951', '1914',
#        '1954', '1958', '1907', '1942', '1918', '1943', '1921', '1927',
#        '1941', '1939', '1940', '1937', '1950', '1946', '1916', '1948',
#        '1934', '1912', '1911', '1926', '1933', '1936', '1925', '1932',
#        '1928', '1917', '1920', '1931', '1913', '1895', '1922', '1923',
#        '1924', '1900', '1908', '1915', '1910', '1897', '1905', '1909',
#        '1903', '1902', '1901', '1906', '1904', '1898', '1896', '1899',
#        '2012', '2014', '2020', '2015', '2011', '1894', '1892', '1893',
#        '1891', '1888', '1890', '2022', '1889', '2023', '2024', '2025',
#        '2027', '2026', '2028', '1878', '1877', '1882', '1881', '1887',
#        '1874', '1883', '1885'], dtype=object)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
titles['startYear'] = pd.to_numeric(titles['startYear'], errors='coerce').astype('Int64')

# %%
titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8407399 entries, 0 to 8407398
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       Int64
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: Int64(1), object(8)
# memory usage: 585.3+ MB

# %%
titles.sort_values(by='startYear').head(2)
# Out:
#              tconst titleType       primaryTitle      originalTitle isAdult  \
# 5329521   tt3155794     short   Passage de Venus   Passage de Venus       0
# 3488807  tt14495706     short  La Rosace Magique  La Rosace Magique       0
#
#          startYear endYear runtimeMinutes             genres
# 5329521       1874      \N              1  Documentary,Short
# 3488807       1877      \N              1    Animation,Short

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 제목(title)이 "Hamlet"인 영화는 몇 개가 있나요?
# </div>

# %%
del titles_order

# %%
titles[
    titles['primaryTitle'] == 'Hamlet'
].shape[0]
# Out:
# 133

# %%
titles.query("primaryTitle == 'Hamlet'").shape[0]
# Out:
# 133

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 제목(title)이 "Treasure Island"인 영화를 제작년도(year)의 오름차순에 따라 표시하세요
# </div>

# %%
titles[
    titles['primaryTitle'] == 'Treasure Island'
].sort_values(by='startYear')
# Out:
#              tconst  titleType     primaryTitle    originalTitle isAdult  \
# 2511      tt0002538      short  Treasure Island  Treasure Island       0
# 5032142   tt2440348      short  Treasure Island  Treasure Island       0
# 9589      tt0009721      movie  Treasure Island  Treasure Island       0
# 11620     tt0011785      movie  Treasure Island  Treasure Island       0
# 25459     tt0025907      movie  Treasure Island  Treasure Island       0
# ...             ...        ...              ...              ...     ...
# 6917550   tt6727462  tvEpisode  Treasure Island  Treasure Island       0
# 3809301  tt15075064  tvEpisode  Treasure Island  Treasure Island       0
# 1574276  tt11064450      movie  Treasure Island  Treasure Island       0
# 4323630   tt1659339      movie  Treasure Island  Treasure Island       0
# 7838572   tt8709864   tvSeries  Treasure Island  Treasure Island       0
#
#          startYear endYear runtimeMinutes                 genres
# 2511          1912      \N             \N        Adventure,Short
# 5032142       1913      \N             \N         Short,Thriller
# 9589          1917      \N             60              Adventure
# 11620         1920      \N             76              Adventure
# 25459         1934      \N            110       Adventure,Family
# ...            ...     ...            ...                    ...
# 6917550       2019      \N             71  Drama,Fantasy,Mystery
# 3809301       2021      \N             \N       Animation,Comedy
# 1574276       <NA>      \N             \N              Adventure
# 4323630       <NA>      \N             \N              Adventure
# 7838572       <NA>      \N             \N             Reality-TV
#
# [74 rows x 9 columns]

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 1950년에서 1959년 사이 몇 개의 영화가 만들어졌나요?(1950 <= 제작년도 <= 1959)
# </div>

# %%
titles[
    titles['startYear'].between(1950, 1959)
].shape[0]
# Out:
# 118649

# %% [markdown]
# # 타이타닉 자료에서 그룹별 연산하기

# %% [markdown]
# 원격 DB에 접속해서 titanic 데이터베이스 안에 있는 p_info, t_info, survived 테이블을 불러와 합치고 아래의 문제를 풀어보세요.<br>
# <id:kict00, pw:kict00, ip:221.155.18.165:3306, db:titanic>

# %%
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

engine= create_engine('mysql+pymysql://kict11:kict11@221.155.18.165:3306/titanic')
conn = engine.connect()

passenger = pd.read_sql('p_info',con=conn,index_col=0)
ticket = pd.read_sql('t_info',con=conn,index_col=0)
survived = pd.read_sql('survived',con=conn,index_col=0)

# %%
conn.close()

# %%
passenger.head(1)
# Out:
#    PassengerId                     Name   Sex   Age  SibSp  Parch
# 0            1  Braund, Mr. Owen Harris  male  22.0      1      0

# %%
ticket.head(1)
# Out:
#    PassengerId     Ticket  Pclass  Fare Cabin Embarked
# 0            1  A/5 21171       3  7.25  None        S

# %%
survived.head(1)
# Out:
#    PassengerId  Survived
# 0            1         0

# %%
titanic = pd.merge(passenger, ticket, on='PassengerId')
titanic = pd.merge(titanic, survived, on='PassengerId')
titanic.head(1)
# Out:
#    PassengerId                     Name   Sex   Age  SibSp  Parch     Ticket  \
# 0            1  Braund, Mr. Owen Harris  male  22.0      1      0  A/5 21171
#
#    Pclass  Fare Cabin Embarked  Survived
# 0       3  7.25  None        S         0

# %%
# 열순서 바꾸기
col = titanic.pop('Survived')  # 'Survived' 열을 빼내서 변수에 저장
titanic.insert(2, 'Survived', col)  # 세 번째 위치에 'Survived' 열을 넣음

# %%
titanic.head(1)
# Out:
#    PassengerId                     Name  Survived   Sex   Age  SibSp  Parch  \
# 0            1  Braund, Mr. Owen Harris         0  male  22.0      1      0
#
#       Ticket  Pclass  Fare Cabin Embarked
# 0  A/5 21171       3  7.25  None        S

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 데이터의 상위 5개 행을 출력하세요.
# </div>

# %%
titanic.head(5)
# Out:
#    PassengerId                                               Name  Survived  \
# 0            1                            Braund, Mr. Owen Harris         0
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2            3                             Heikkinen, Miss. Laina         1
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 4            5                           Allen, Mr. William Henry         0
#
#       Sex   Age  SibSp  Parch            Ticket  Pclass     Fare Cabin  \
# 0    male  22.0      1      0         A/5 21171       3   7.2500  None
# 1  female  38.0      1      0          PC 17599       1  71.2833   C85
# 2  female  26.0      0      0  STON/O2. 3101282       3   7.9250  None
# 3  female  35.0      1      0            113803       1  53.1000  C123
# 4    male  35.0      0      0            373450       3   8.0500  None
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 데이터의 정보(info)를 출력하세요.
# </div>

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Name         891 non-null    object
#  2   Survived     891 non-null    int64
#  3   Sex          891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Pclass       891 non-null    int64
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 데이터의 기술통계(describe)를 확인하세요.
# </div>

# %%
titanic.describe()
# Out:
#        PassengerId    Survived         Age       SibSp       Parch  \
# count   891.000000  891.000000  714.000000  891.000000  891.000000
# mean    446.000000    0.383838   29.699118    0.523008    0.381594
# std     257.353842    0.486592   14.526497    1.102743    0.806057
# min       1.000000    0.000000    0.420000    0.000000    0.000000
# 25%     223.500000    0.000000   20.125000    0.000000    0.000000
# 50%     446.000000    0.000000   28.000000    0.000000    0.000000
# 75%     668.500000    1.000000   38.000000    1.000000    0.000000
# max     891.000000    1.000000   80.000000    8.000000    6.000000
#
#            Pclass        Fare
# count  891.000000  891.000000
# mean     2.308642   32.204208
# std      0.836071   49.693429
# min      1.000000    0.000000
# 25%      2.000000    7.910400
# 50%      3.000000   14.454200
# 75%      3.000000   31.000000
# max      3.000000  512.329200

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 처음 100명의 데이터를 출력하세요.
# </div>

# %%
titanic.iloc[:100]
# Out:
#     PassengerId                                               Name  Survived  \
# 0             1                            Braund, Mr. Owen Harris         0
# 1             2  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2             3                             Heikkinen, Miss. Laina         1
# 3             4       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 4             5                           Allen, Mr. William Henry         0
# ..          ...                                                ...       ...
# 95           96                        Shorney, Mr. Charles Joseph         0
# 96           97                          Goldschmidt, Mr. George B         0
# 97           98                    Greenfield, Mr. William Bertram         1
# 98           99               Doling, Mrs. John T (Ada Julia Bone)         1
# 99          100                                  Kantor, Mr. Sinai         0
#
#        Sex   Age  SibSp  Parch            Ticket  Pclass     Fare    Cabin  \
# 0     male  22.0      1      0         A/5 21171       3   7.2500     None
# 1   female  38.0      1      0          PC 17599       1  71.2833      C85
# 2   female  26.0      0      0  STON/O2. 3101282       3   7.9250     None
# 3   female  35.0      1      0            113803       1  53.1000     C123
# 4     male  35.0      0      0            373450       3   8.0500     None
# ..     ...   ...    ...    ...               ...     ...      ...      ...
# 95    male   NaN      0      0            374910       3   8.0500     None
# 96    male  71.0      0      0          PC 17754       1  34.6542       A5
# 97    male  23.0      0      1          PC 17759       1  63.3583  D10 D12
# 98  female  34.0      0      1            231919       2  23.0000     None
# 99    male  34.0      1      0            244367       2  26.0000     None
#
#    Embarked
# 0         S
# 1         C
# 2         S
# 3         S
# 4         S
# ..      ...
# 95        S
# 96        C
# 97        C
# 98        S
# 99        S
#
# [100 rows x 12 columns]

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 인덱스가 10~20인 데이터를 출력하세요.
# </div>

# %%
titanic.iloc[10:21]
# Out:
#     PassengerId                                               Name  Survived  \
# 10           11                    Sandstrom, Miss. Marguerite Rut         1
# 11           12                           Bonnell, Miss. Elizabeth         1
# 12           13                     Saundercock, Mr. William Henry         0
# 13           14                        Andersson, Mr. Anders Johan         0
# 14           15               Vestrom, Miss. Hulda Amanda Adolfina         0
# 15           16                   Hewlett, Mrs. (Mary D Kingcome)          1
# 16           17                               Rice, Master. Eugene         0
# 17           18                       Williams, Mr. Charles Eugene         1
# 18           19  Vander Planke, Mrs. Julius (Emelia Maria Vande...         0
# 19           20                            Masselmani, Mrs. Fatima         1
# 20           21                               Fynney, Mr. Joseph J         0
#
#        Sex   Age  SibSp  Parch     Ticket  Pclass     Fare Cabin Embarked
# 10  female   4.0      1      1    PP 9549       3  16.7000    G6        S
# 11  female  58.0      0      0     113783       1  26.5500  C103        S
# 12    male  20.0      0      0  A/5. 2151       3   8.0500  None        S
# 13    male  39.0      1      5     347082       3  31.2750  None        S
# 14  female  14.0      0      0     350406       3   7.8542  None        S
# 15  female  55.0      0      0     248706       2  16.0000  None        S
# 16    male   2.0      4      1     382652       3  29.1250  None        Q
# 17    male   NaN      0      0     244373       2  13.0000  None        S
# 18  female  31.0      1      0     345763       3  18.0000  None        S
# 19  female   NaN      0      0       2649       3   7.2250  None        C
# 20    male  35.0      0      0     239865       2  26.0000  None        S

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 컬럼 이름을 모두 출력하세요.
# </div>

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Name', 'Survived', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Pclass', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 데이터의 shape를 확인하세요.
# </div>

# %%
titanic.shape
# Out:
# (891, 12)

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 'Age' 컬럼의 평균을 구하세요.
# </div>

# %%
titanic['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 'Survived' 컬럼의 고유값을 확인하세요.
# </div>

# %%
titanic['Survived'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 나이가 30 이상인 승객만 출력하세요.
# </div>

# %%
titanic[
    titanic['Age'] >= 30
]
# Out:
#      PassengerId                                               Name  Survived  \
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 4              5                           Allen, Mr. William Henry         0
# 6              7                            McCarthy, Mr. Timothy J         0
# 11            12                           Bonnell, Miss. Elizabeth         1
# ..           ...                                                ...       ...
# 873          874                        Vander Cruyssen, Mr. Victor         0
# 879          880      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)         1
# 881          882                                 Markun, Mr. Johann         0
# 885          886               Rice, Mrs. William (Margaret Norton)         0
# 890          891                                Dooley, Mr. Patrick         0
#
#         Sex   Age  SibSp  Parch    Ticket  Pclass     Fare Cabin Embarked
# 1    female  38.0      1      0  PC 17599       1  71.2833   C85        C
# 3    female  35.0      1      0    113803       1  53.1000  C123        S
# 4      male  35.0      0      0    373450       3   8.0500  None        S
# 6      male  54.0      0      0     17463       1  51.8625   E46        S
# 11   female  58.0      0      0    113783       1  26.5500  C103        S
# ..      ...   ...    ...    ...       ...     ...      ...   ...      ...
# 873    male  47.0      0      0    345765       3   9.0000  None        S
# 879  female  56.0      0      1     11767       1  83.1583   C50        C
# 881    male  33.0      0      0    349257       3   7.8958  None        S
# 885  female  39.0      0      5    382652       3  29.1250  None        Q
# 890    male  32.0      0      0    370376       3   7.7500  None        Q
#
# [330 rows x 12 columns]

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 성별이 'female'이고 생존한 승객만 출력하세요.
# </div>

# %%
titanic[
    (titanic['Sex'] == 'female') &
    (titanic['Survived'] == 1)
]
# Out:
#      PassengerId                                               Name  Survived  \
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2              3                             Heikkinen, Miss. Laina         1
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 8              9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1
# 9             10                Nasser, Mrs. Nicholas (Adele Achem)         1
# ..           ...                                                ...       ...
# 874          875              Abelson, Mrs. Samuel (Hannah Wizosky)         1
# 875          876                   Najib, Miss. Adele Kiamie "Jane"         1
# 879          880      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)         1
# 880          881       Shelley, Mrs. William (Imanita Parrish Hall)         1
# 887          888                       Graham, Miss. Margaret Edith         1
#
#         Sex   Age  SibSp  Parch            Ticket  Pclass     Fare Cabin  \
# 1    female  38.0      1      0          PC 17599       1  71.2833   C85
# 2    female  26.0      0      0  STON/O2. 3101282       3   7.9250  None
# 3    female  35.0      1      0            113803       1  53.1000  C123
# 8    female  27.0      0      2            347742       3  11.1333  None
# 9    female  14.0      1      0            237736       2  30.0708  None
# ..      ...   ...    ...    ...               ...     ...      ...   ...
# 874  female  28.0      1      0         P/PP 3381       2  24.0000  None
# 875  female  15.0      0      0              2667       3   7.2250  None
# 879  female  56.0      0      1             11767       1  83.1583   C50
# 880  female  25.0      0      1            230433       2  26.0000  None
# 887  female  19.0      0      0            112053       1  30.0000   B42
#
#     Embarked
# 1          C
# 2          S
# 3          S
# 8          S
# 9          C
# ..       ...
# 874        C
# 875        C
# 879        C
# 880        S
# 887        S
#
# [233 rows x 12 columns]

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 나이가 10살 이하이고 요금이 20 이상인 승객을 출력하세요.
# </div>

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Name', 'Survived', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Pclass', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic[
    (titanic['Age'] <= 10) &
    (titanic['Fare'] >= 20)
]
# Out:
#      PassengerId                                             Name  Survived  \
# 7              8                   Palsson, Master. Gosta Leonard         0
# 16            17                             Rice, Master. Eugene         0
# 24            25                    Palsson, Miss. Torborg Danira         0
# 43            44         Laroche, Miss. Simonne Marie Anne Andree         1
# 50            51                       Panula, Master. Juha Niilo         0
# 58            59                     West, Miss. Constance Mirium         1
# 63            64                            Skoog, Master. Harald         0
# 78            79                    Caldwell, Master. Alden Gates         1
# 119          120                Andersson, Miss. Ellis Anna Maria         0
# 147          148                 Ford, Miss. Robina Maggie "Ruby"         0
# 164          165                     Panula, Master. Eino Viljami         0
# 165          166  Goldsmith, Master. Frank John William "Frankie"         1
# 171          172                             Rice, Master. Arthur         0
# 182          183            Asplund, Master. Clarence Gustaf Hugo         0
# 183          184                        Becker, Master. Richard F         1
# 184          185              Kink-Heilmann, Miss. Luise Gretchen         1
# 193          194                       Navratil, Master. Michel M         1
# 233          234                   Asplund, Miss. Lillian Gertrud         1
# 237          238                 Collyer, Miss. Marjorie "Lottie"         1
# 261          262                Asplund, Master. Edvin Rojj Felix         1
# 278          279                               Rice, Master. Eric         0
# 297          298                     Allison, Miss. Helen Loraine         0
# 305          306                   Allison, Master. Hudson Trevor         1
# 340          341                   Navratil, Master. Edmond Roger         1
# 374          375                       Palsson, Miss. Stina Viola         0
# 386          387                  Goodwin, Master. Sidney Leonard         0
# 419          420                        Van Impe, Miss. Catharina         0
# 445          446                        Dodge, Master. Washington         1
# 480          481                   Goodwin, Master. Harold Victor         0
# 530          531                         Quick, Miss. Phyllis May         1
# 535          536                           Hart, Miss. Eva Miriam         1
# 541          542             Andersson, Miss. Ingeborg Constanzia         0
# 549          550                   Davies, Master. John Morgan Jr         1
# 618          619                      Becker, Miss. Marion Louise         1
# 634          635                               Skoog, Miss. Mabel         0
# 642          643                    Skoog, Miss. Margit Elizabeth         0
# 720          721                Harper, Miss. Annie Jessie "Nina"         1
# 750          751                                Wells, Miss. Joan         1
# 787          788                        Rice, Master. George Hugh         0
# 788          789                       Dean, Master. Bertram Vere         1
# 813          814               Andersson, Miss. Ebba Iris Alfrida         0
# 819          820                     Skoog, Master. Karl Thorsten         0
# 824          825                     Panula, Master. Urho Abraham         0
# 827          828                            Mallet, Master. Andre         1
# 850          851          Andersson, Master. Sigvard Harald Elias         0
#
#         Sex    Age  SibSp  Parch           Ticket  Pclass      Fare    Cabin  \
# 7      male   2.00      3      1           349909       3   21.0750     None
# 16     male   2.00      4      1           382652       3   29.1250     None
# 24   female   8.00      3      1           349909       3   21.0750     None
# 43   female   3.00      1      2    SC/Paris 2123       2   41.5792     None
# 50     male   7.00      4      1          3101295       3   39.6875     None
# 58   female   5.00      1      2       C.A. 34651       2   27.7500     None
# 63     male   4.00      3      2           347088       3   27.9000     None
# 78     male   0.83      0      2           248738       2   29.0000     None
# 119  female   2.00      4      2           347082       3   31.2750     None
# 147  female   9.00      2      2       W./C. 6608       3   34.3750     None
# 164    male   1.00      4      1          3101295       3   39.6875     None
# 165    male   9.00      0      2           363291       3   20.5250     None
# 171    male   4.00      4      1           382652       3   29.1250     None
# 182    male   9.00      4      2           347077       3   31.3875     None
# 183    male   1.00      2      1           230136       2   39.0000       F4
# 184  female   4.00      0      2           315153       3   22.0250     None
# 193    male   3.00      1      1           230080       2   26.0000       F2
# 233  female   5.00      4      2           347077       3   31.3875     None
# 237  female   8.00      0      2       C.A. 31921       2   26.2500     None
# 261    male   3.00      4      2           347077       3   31.3875     None
# 278    male   7.00      4      1           382652       3   29.1250     None
# 297  female   2.00      1      2           113781       1  151.5500  C22 C26
# 305    male   0.92      1      2           113781       1  151.5500  C22 C26
# 340    male   2.00      1      1           230080       2   26.0000       F2
# 374  female   3.00      3      1           349909       3   21.0750     None
# 386    male   1.00      5      2          CA 2144       3   46.9000     None
# 419  female  10.00      0      2           345773       3   24.1500     None
# 445    male   4.00      0      2            33638       1   81.8583      A34
# 480    male   9.00      5      2          CA 2144       3   46.9000     None
# 530  female   2.00      1      1            26360       2   26.0000     None
# 535  female   7.00      0      2     F.C.C. 13529       2   26.2500     None
# 541  female   9.00      4      2           347082       3   31.2750     None
# 549    male   8.00      1      1       C.A. 33112       2   36.7500     None
# 618  female   4.00      2      1           230136       2   39.0000       F4
# 634  female   9.00      3      2           347088       3   27.9000     None
# 642  female   2.00      3      2           347088       3   27.9000     None
# 720  female   6.00      0      1           248727       2   33.0000     None
# 750  female   4.00      1      1            29103       2   23.0000     None
# 787    male   8.00      4      1           382652       3   29.1250     None
# 788    male   1.00      1      2        C.A. 2315       3   20.5750     None
# 813  female   6.00      4      2           347082       3   31.2750     None
# 819    male  10.00      3      2           347088       3   27.9000     None
# 824    male   2.00      4      1          3101295       3   39.6875     None
# 827    male   1.00      0      2  S.C./PARIS 2079       2   37.0042     None
# 850    male   4.00      4      2           347082       3   31.2750     None
#
#     Embarked
# 7          S
# 16         Q
# 24         S
# 43         C
# 50         S
# 58         S
# 63         S
# 78         S
# 119        S
# 147        S
# 164        S
# 165        S
# 171        Q
# 182        S
# 183        S
# 184        S
# 193        S
# 233        S
# 237        S
# 261        S
# 278        Q
# 297        S
# 305        S
# 340        S
# 374        S
# 386        S
# 419        S
# 445        S
# 480        S
# 530        S
# 535        S
# 541        S
# 549        S
# 618        S
# 634        S
# 642        S
# 720        S
# 750        S
# 787        Q
# 788        S
# 813        S
# 819        S
# 824        S
# 827        C
# 850        S

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 나이가 결측치인 데이터를 출력하세요.
# </div>

# %%
titanic[
    titanic['Age'].isna()
]
# Out:
#      PassengerId                                      Name  Survived     Sex  \
# 5              6                          Moran, Mr. James         0    male
# 17            18              Williams, Mr. Charles Eugene         1    male
# 19            20                   Masselmani, Mrs. Fatima         1  female
# 26            27                   Emir, Mr. Farred Chehab         0    male
# 28            29             O'Dwyer, Miss. Ellen "Nellie"         1  female
# ..           ...                                       ...       ...     ...
# 859          860                          Razi, Mr. Raihed         0    male
# 863          864         Sage, Miss. Dorothy Edith "Dolly"         0  female
# 868          869               van Melkebeke, Mr. Philemon         0    male
# 878          879                        Laleff, Mr. Kristo         0    male
# 888          889  Johnston, Miss. Catherine Helen "Carrie"         0  female
#
#      Age  SibSp  Parch      Ticket  Pclass     Fare Cabin Embarked
# 5    NaN      0      0      330877       3   8.4583  None        Q
# 17   NaN      0      0      244373       2  13.0000  None        S
# 19   NaN      0      0        2649       3   7.2250  None        C
# 26   NaN      0      0        2631       3   7.2250  None        C
# 28   NaN      0      0      330959       3   7.8792  None        Q
# ..   ...    ...    ...         ...     ...      ...   ...      ...
# 859  NaN      0      0        2629       3   7.2292  None        C
# 863  NaN      8      2    CA. 2343       3  69.5500  None        S
# 868  NaN      0      0      345777       3   9.5000  None        S
# 878  NaN      0      0      349217       3   7.8958  None        S
# 888  NaN      1      2  W./C. 6607       3  23.4500  None        S
#
# [177 rows x 12 columns]

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 나이를 기준으로 오름차순 정렬하세요.
# </div>

# %%
titanic.sort_values(by='Age')
# Out:
#      PassengerId                                      Name  Survived     Sex  \
# 803          804           Thomas, Master. Assad Alexander         1    male
# 755          756                 Hamalainen, Master. Viljo         1    male
# 469          470             Baclini, Miss. Helene Barbara         1  female
# 644          645                    Baclini, Miss. Eugenie         1  female
# 78            79             Caldwell, Master. Alden Gates         1    male
# ..           ...                                       ...       ...     ...
# 859          860                          Razi, Mr. Raihed         0    male
# 863          864         Sage, Miss. Dorothy Edith "Dolly"         0  female
# 868          869               van Melkebeke, Mr. Philemon         0    male
# 878          879                        Laleff, Mr. Kristo         0    male
# 888          889  Johnston, Miss. Catherine Helen "Carrie"         0  female
#
#       Age  SibSp  Parch      Ticket  Pclass     Fare Cabin Embarked
# 803  0.42      0      1        2625       3   8.5167  None        C
# 755  0.67      1      1      250649       2  14.5000  None        S
# 469  0.75      2      1        2666       3  19.2583  None        C
# 644  0.75      2      1        2666       3  19.2583  None        C
# 78   0.83      0      2      248738       2  29.0000  None        S
# ..    ...    ...    ...         ...     ...      ...   ...      ...
# 859   NaN      0      0        2629       3   7.2292  None        C
# 863   NaN      8      2    CA. 2343       3  69.5500  None        S
# 868   NaN      0      0      345777       3   9.5000  None        S
# 878   NaN      0      0      349217       3   7.8958  None        S
# 888   NaN      1      2  W./C. 6607       3  23.4500  None        S
#
# [891 rows x 12 columns]

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 요금을 기준으로 내림차순 정렬하고 상위 5명만 출력하세요.
# </div>

# %%
titanic.sort_values(by='Fare', ascending=False).head(5)
# Out:
#      PassengerId                                Name  Survived     Sex   Age  \
# 737          738              Lesurer, Mr. Gustave J         1    male  35.0
# 679          680  Cardeza, Mr. Thomas Drake Martinez         1    male  36.0
# 258          259                    Ward, Miss. Anna         1  female  35.0
# 438          439                   Fortune, Mr. Mark         0    male  64.0
# 88            89          Fortune, Miss. Mabel Helen         1  female  23.0
#
#      SibSp  Parch    Ticket  Pclass      Fare        Cabin Embarked
# 737      0      0  PC 17755       1  512.3292         B101        C
# 679      0      1  PC 17755       1  512.3292  B51 B53 B55        C
# 258      0      0  PC 17755       1  512.3292         None        C
# 438      1      4     19950       1  263.0000  C23 C25 C27        S
# 88       3      2     19950       1  263.0000  C23 C25 C27        S

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 성별로 그룹화하여 생존률 평균을 구하세요.
# </div>

# %%
titanic[['Sex','Survived']].groupby(['Sex']).value_counts(sort=False)
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: count, dtype: int64

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: Pclass별 평균 나이를 구하세요.
# </div>

# %%
titanic[['Pclass', 'Age']].groupby('Pclass').mean()
# Out:
#               Age
# Pclass
# 1       38.233441
# 2       29.877630
# 3       25.140620

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 'Age'에 10을 더한 값을 새로운 컬럼 'Age_plus_10'으로 추가하세요.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 'Age'가 18 이상이면 '성인', 아니면 '미성년'으로 분류하는 컬럼을 추가하세요.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 'Age'의 결측치를 평균으로 채우세요.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 'Cabin' 컬럼의 결측치를 'Unknown'으로 채우세요.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 중복된 'Ticket' 값을 제거하고 몇 개가 남는지 출력하세요.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 'Embarked' 컬럼의 고유값과 각각의 개수를 출력하세요.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 인덱스를 'PassengerId'로 설정하세요.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 인덱스를 초기화하세요.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 성별과 Pclass의 생존률을 피벗 테이블로 만드세요.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: groupby()를 사용하여 각 성별(sex)의 평균 나이(age)를 구하세요.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 전체 승객(passenger)의 평균 생존율을 구하세요.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 25세 이하 승객의 생존율을 구하세요. (힌트: 불리언 인덱싱)
# </div>

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 남성의 생존율을 구하세요. 여성의 생존율을 구하세요. (힌트: 불리언 인덱싱)
# </div>

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 생존율을 구하는 함수가 작성되어 있습니다. 성별 생존율을 groupby를 활용해 구하기 위해 ?부분을 알맞게 채워주세요.
# </div>

# %%
def survival_ratio(survived):
    return survived.sum() / len(survived)
